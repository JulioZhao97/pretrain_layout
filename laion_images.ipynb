# %%
import pandas as pd

# %%
laion = pd.read_csv("/mnt/hwfile/opendatalab/linyiqi/laion_40m.csv")

# %%
laion.head(10)
# Out:
#    Unnamed: 0.2  Unnamed: 0  Unnamed: 0.1  \
# 0        570615       71905       83082.0
# 1        575455        5459        5731.0
# 2        721425        2877           NaN
# 3        505568       67643       75648.0
# 4        418403       72579           NaN
# 5        271494       45692       55344.0
# 6        976504      142561      148520.0
# 7        832991       40717       46504.0
# 8        801504       57108           NaN
# 9         58494       24352           NaN
#
#                                                 path    scores  ase_scores  \
# 0  s3://laion5b/LAION-5B/laion2B-en/00013/1002527...  0.772461    4.850348
# 1  s3://laion5b/LAION-5B/laion2B-en/00084/1553481...  0.769531    5.011578
# 2  s3://laion5b/LAION-5B/laion2B-en/00081/1248625...  0.785156    5.000473
# 3  s3://laion5b/LAION-5B/laion2B-en/00098/2572271...  0.798828    4.840493
# 4  s3://laion5b/LAION-5B/laion2B-en/00044/2054100...  0.866211    4.944951
# ...

# %%
laion.shape
# Out:
# (40000000, 8)

# %%
print(laion.iloc[0]['path'])
# Out:
# s3://laion5b/LAION-5B/laion2B-en/00013/1002527007063.0.jpg

# %%
laion1m = laion.sample(n=1000000)

# %%
laion1m.to_csv("laion_1m.csv")

# %%
from PIL import Image

# %%
display(Image.open("/mnt/hwfile/opendatalab/zhaozhiyuan/laion1m_background/2787740011382.0.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=473x593>

# %%
display(Image.open("/mnt/hwfile/opendatalab/zhaozhiyuan/laion1m/2787740011382.0.jpg"))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=473x593>
